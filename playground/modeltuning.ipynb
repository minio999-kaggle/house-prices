# %%
'''
Main module for preprocessing.
'''
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler

PATH = '../data/train.csv'

def encoding_values(df):
    '''
    encode categorical data to float
    Parameters:
        dataframe (pandas.DataFrame): DataFrame on which to operate
    Returns:
        pandas.DataFrame
    '''
    df_objects = (df.dtypes=='object')
    object_cols = list(df_objects[df_objects].index)
    ordinal_encoder = OrdinalEncoder()
    df[object_cols] = ordinal_encoder.fit_transform(df[object_cols])
    return df

def impute_values(df):
    '''
    Impute missing values in features
    Parameters:
        df (pandas.DataFrame): Dataframe on which to operate
    Returns:
        pandas.DataFrame
    '''
    imputer = SimpleImputer()
    imputer.fit(df)
    imputed_df = pd.DataFrame(imputer.transform(df))
    imputed_df.columns = df.columns
    return imputed_df

def scaling_values(df):
    '''
    Scaling features
    Parameters:
        df (pandas.DataFrame): Dataframe on which to operate
    Returns:
        pandas.DataFrame
    '''

    scaler = MinMaxScaler()
    x_train = df.drop(['Id', 'SalePrice'], axis=1)
    scaler.fit(x_train)
    scaled_data = scaler.transform(x_train)
    scaled_data = pd.DataFrame(scaled_data, columns=x_train.columns)
    scaled_data.insert(loc=0, column='Id', value=df['Id'])
    scaled_data['SalePrice'] = df['SalePrice']
    return scaled_data

def apply_preprocessing(df):
    '''
    Applying data cleaning functions to data sets
    Paramters:
        dataframe (pandas.DataFrame): Dataframe on which to operate
    Retruns:
        pandas.DataFrame
    '''
    # since some columns have to much NaN we will drop them here
    df = df.drop(columns=['Alley', 'PoolQC', 'Fence', 'MiscFeature'])
    df = encoding_values(df)
    df = impute_values(df)
    df = scaling_values(df)
    return df

def get_df():
    '''
    Sharing dataframe after aplying preprocessing
    Returns:
        pandas.DataFrame
    '''
    df = pd.read_csv(PATH)
    df = apply_preprocessing(df)
    return df

# %%
from sklearn.model_selection import KFold
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

LABEL = 'SalePrice'

df = get_df()

X = df.drop(['SalePrice', 'Id'], axis=1)
y = df[LABEL]

k_fold = KFold(
n_splits=5,
shuffle=True,
random_state=42
)

scores = []

# %%
scores = []
for train_index, test_index in k_fold.split(X):
    X_train, X_test = X.loc[train_index], X.loc[test_index]
    y_train, y_test = y.loc[train_index], y.loc[test_index]
    # {'depth': 6, 'iterations': 100, 'learning_rate': 0.1}
    # 26948.184676065393
    # 27983
    # 27144
    # 26974
    # 26815 depth = 7
    # 26750 iterations = 1250
    # 26719 iterations = 1500
    reg = CatBoostRegressor(depth=7, iterations=1500, learning_rate = 0.025, logging_level='Silent')
    # reg = CatBoostRegressor(logging_level='Silent')
    reg.fit(X_train, y_train)

    y_predict = reg.predict(X_test)

    acc_score = np.sqrt(mean_squared_error(y_test, y_predict))
        
    print(acc_score)

    scores.append(acc_score)

print()
print("Average:", np.sum(scores)/5)
print("Std:", round(np.std(scores), 3))
# Out:
# 26806.4949386533
# 23292.420516271683
# 37325.670510667245
# 26786.487463836613
# 19385.578002562106
#
# Average: 26719.33028639819
# Std: 5967.147

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

x_reg = CatBoostRegressor()

parameters = {'depth'         : [5,25, 50, 100],
            'learning_rate' : [0.01, 0.025, 0.05, 0.1],
            'iterations'    : [30, 50, 100, 500, 1000],
            'logging_level': ['Silent']
}

grid = GridSearchCV(estimator=x_reg, param_grid = parameters, cv = 5, n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 300 fits failed out of a total of 400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 300 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/conda/lib/python3.9/site-packages/catboost/core.py", line 5590, in fit
#     return self._fit(X, y, cat_features, None, None, None, sample_weight, None, None, None, None, baseline,
#   File "/opt/conda/lib/python3.9/site-packages/catboost/core.py", line 2262, in _fit
#     train_params = self._prepare_train_params(
#   File "/opt/conda/lib/python3.9/site-packages/catboost/core.py", line 2194, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 6032, in _catboost._check_train_params
#   File "_catboost.pyx", line 6051, in _catboost._check_train_params
# _catboost.CatBoostError: catboost/private/libs/options/oblivious_tree_options.cpp:125: Maximum tree depth is 16
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.28144913 0.53849564 0.73502023 0.8382683  0.41547574 0.68532376
#  0.82325737 0.86389417 0.62501036 0.82463203 0.87254242 0.88501903
#  0.87401884 0.90053502 0.90332675 0.89775138 0.8944705  0.90625734
#  0.90440101 0.89744095        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan]
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=<catboost.core.CatBoostRegressor object at 0x7f62f7b28c40>,
#              n_jobs=-1,
#              param_grid={'depth': [5, 25, 50, 100],
#                          'iterations': [30, 50, 100, 500, 1000],
#                          'learning_rate': [0.01, 0.025, 0.05, 0.1],
#                          'logging_level': ['Silent']})

# %%
    print(" Results from Grid Search " )
    print("\n The best estimator across ALL searched params:\n", grid.best_estimator_)
    print("\n The best score across ALL searched params:\n", grid.best_score_)
    print("\n The best parameters across ALL searched params:\n", grid.best_params_)
# Out:
#  Results from Grid Search
#
#  The best estimator across ALL searched params:
#  <catboost.core.CatBoostRegressor object at 0x7f62f7abd070>
#
#  The best score across ALL searched params:
#  0.9062573423693564
#
#  The best parameters across ALL searched params:
#  {'depth': 5, 'iterations': 1000, 'learning_rate': 0.025, 'logging_level': 'Silent'}
# 7:	learn: 51099.6870006	total: 1.59s	remaining: 18.3s
# 8:	learn: 48639.4946803	total: 1.81s	remaining: 18.3s
# 9:	learn: 46360.1761728	total: 1.89s	remaining: 17s
# 10:	learn: 44330.6691140	total: 2.05s	remaining: 16.6s
# 11:	learn: 42657.6929351	total: 2.3s	remaining: 16.9s
# 12:	learn: 40905.7242840	total: 2.43s	remaining: 16.3s
# 13:	learn: 39380.4424769	total: 2.75s	remaining: 16.9s
# 14:	learn: 37826.9809032	total: 3.04s	remaining: 17.2s
# 15:	learn: 36463.6268669	total: 3.49s	remaining: 18.3s
# 16:	learn: 35106.7314604	total: 3.8s	remaining: 18.6s
# 17:	learn: 34020.9323356	total: 4.22s	remaining: 19.2s
# 18:	learn: 33042.1688418	total: 4.36s	remaining: 18.6s
# 19:	learn: 32082.2366764	total: 4.51s	remaining: 18s
# 20:	learn: 31242.1610335	total: 4.8s	remaining: 18.1s
# 21:	learn: 30214.6607795	total: 5.16s	remaining: 18.3s
# 22:	learn: 29244.0710012	total: 5.45s	remaining: 18.3s
# 23:	learn: 28498.4446523	total: 5.66s	remaining: 17.9s
# 24:	learn: 27700.3031518	total: 5.75s	remaining: 17.2s
# 25:	learn: 26879.3780465	total: 5.9s	remaining: 16.8s
# 26:	learn: 26044.8896829	total: 6.2s	remaining: 16.8s
# 27:	learn: 25424.2605587	total: 6.32s	remaining: 16.2s
# 28:	learn: 24872.2913803	total: 6.5s	remaining: 15.9s
# 29:	learn: 24242.4752544	total: 6.77s	remaining: 15.8s
# 30:	learn: 23647.8899464	total: 6.87s	remaining: 15.3s
# 31:	learn: 23112.4285528	total: 7.28s	remaining: 15.5s
# 32:	learn: 22728.7002298	total: 7.41s	remaining: 15.1s
# 33:	learn: 22263.2814013	total: 7.62s	remaining: 14.8s
# 34:	learn: 21754.3214985	total: 7.74s	remaining: 14.4s
# 35:	learn: 21323.3902761	total: 7.82s	remaining: 13.9s
# 36:	learn: 20927.7558095	total: 8.42s	remaining: 14.3s
# 37:	learn: 20491.5069573	total: 8.77s	remaining: 14.3s
# 38:	learn: 20142.8318441	total: 8.94s	remaining: 14s
# 39:	learn: 19792.2144429	total: 9.13s	remaining: 13.7s
# 40:	learn: 19429.5846235	total: 9.23s	remaining: 13.3s
# 41:	learn: 19132.8536323	total: 9.36s	remaining: 12.9s
# 42:	learn: 18865.6770435	total: 9.57s	remaining: 12.7s
# 43:	learn: 18554.1349241	total: 9.79s	remaining: 12.5s
# 44:	learn: 18291.6222631	total: 9.98s	remaining: 12.2s
# 45:	learn: 17919.4829406	total: 10.2s	remaining: 12s
# 46:	learn: 17613.5937188	total: 10.4s	remaining: 11.7s
# 47:	learn: 17357.6581503	total: 10.6s	remaining: 11.5s
# 48:	learn: 17136.6555363	total: 10.8s	remaining: 11.3s
# 49:	learn: 16937.6384582	total: 11.1s	remaining: 11.1s
# 50:	learn: 16715.5968943	total: 11.2s	remaining: 10.8s
# 51:	learn: 16487.1021805	total: 11.4s	remaining: 10.5s
# 52:	learn: 16302.0041430	total: 11.7s	remaining: 10.3s
# 53:	learn: 16122.4310451	total: 11.8s	remaining: 10.1s
# 54:	learn: 15964.7882608	total: 12s	remaining: 9.81s
# 55:	learn: 15795.6991819	total: 12.2s	remaining: 9.55s
# 56:	learn: 15573.0481034	total: 12.4s	remaining: 9.39s
# 57:	learn: 15325.8345789	total: 12.9s	remaining: 9.32s
# 58:	learn: 15104.4790188	total: 13s	remaining: 9.06s
# 59:	learn: 14962.0115205	total: 13.2s	remaining: 8.79s
# 60:	learn: 14772.7210302	total: 13.5s	remaining: 8.61s
# 61:	learn: 14641.6628228	total: 13.6s	remaining: 8.36s
# 62:	learn: 14488.4490899	total: 13.7s	remaining: 8.07s
# 63:	learn: 14320.2456639	total: 14s	remaining: 7.85s
# 64:	learn: 14179.2759792	total: 14.1s	remaining: 7.58s
# 65:	learn: 14058.6020925	total: 14.2s	remaining: 7.33s
# 66:	learn: 13858.1516450	total: 14.4s	remaining: 7.09s
# 67:	learn: 13691.2714882	total: 14.5s	remaining: 6.8s
# 68:	learn: 13500.3818006	total: 14.6s	remaining: 6.55s
# 69:	learn: 13330.5460838	total: 14.8s	remaining: 6.33s
# 70:	learn: 13176.4156480	total: 14.9s	remaining: 6.08s
# 71:	learn: 13005.9191262	total: 15s	remaining: 5.84s
# 72:	learn: 12943.1264359	total: 15.1s	remaining: 5.59s
# 73:	learn: 12787.1788503	total: 15.3s	remaining: 5.37s
# 74:	learn: 12668.9177276	total: 15.4s	remaining: 5.13s
# 75:	learn: 12526.9180476	total: 15.5s	remaining: 4.9s
# 76:	learn: 12449.3221667	total: 15.6s	remaining: 4.66s
# 77:	learn: 12319.7600085	total: 15.7s	remaining: 4.42s
# 78:	learn: 12183.8909469	total: 15.8s	remaining: 4.19s
# 79:	learn: 12078.5910945	total: 15.8s	remaining: 3.96s
# 80:	learn: 11941.0769083	total: 16s	remaining: 3.76s
# 81:	learn: 11867.4231756	total: 16.1s	remaining: 3.54s
# 82:	learn: 11747.1426895	total: 16.2s	remaining: 3.31s
# 83:	learn: 11642.8109516	total: 16.2s	remaining: 3.09s
# 84:	learn: 11573.3694147	total: 16.3s	remaining: 2.87s
# 85:	learn: 11479.2554005	total: 16.3s	remaining: 2.66s
# 86:	learn: 11381.3824065	total: 16.4s	remaining: 2.45s
# 87:	learn: 11317.9743248	total: 16.4s	remaining: 2.24s
# 88:	learn: 11238.0705138	total: 16.5s	remaining: 2.04s
# 89:	learn: 11207.1892261	total: 16.5s	remaining: 1.83s
# 90:	learn: 11060.1729331	total: 16.6s	remaining: 1.64s
# 91:	learn: 10996.3278600	total: 16.6s	remaining: 1.44s
# 92:	learn: 10984.4795600	total: 16.6s	remaining: 1.25s
# 93:	learn: 10916.3511659	total: 16.7s	remaining: 1.06s
# 94:	learn: 10822.2345602	total: 16.7s	remaining: 880ms
# 95:	learn: 10673.4071852	total: 16.8s	remaining: 699ms
# 96:	learn: 10570.4982236	total: 16.8s	remaining: 520ms
# 97:	learn: 10424.0106355	total: 16.8s	remaining: 344ms
# 98:	learn: 10389.9299549	total: 16.9s	remaining: 171ms
# 99:	learn: 10372.5701836	total: 16.9s	remaining: 0us
# 56:	learn: 57480.3868357	total: 13s	remaining: 9.84s
# 57:	learn: 57209.6368581	total: 13.1s	remaining: 9.51s
# 58:	learn: 56889.0274665	total: 13.2s	remaining: 9.2s
# 59:	learn: 56613.6339070	total: 13.5s	remaining: 9s
# 60:	learn: 56321.6070320	total: 13.8s	remaining: 8.8s
# 61:	learn: 56061.7649626	total: 13.9s	remaining: 8.52s
# 62:	learn: 55748.8176627	total: 14.2s	remaining: 8.31s
# 63:	learn: 55445.6328152	total: 14.4s	remaining: 8.09s
# 64:	learn: 55164.5677089	total: 14.6s	remaining: 7.88s
# 65:	learn: 54888.7900957	total: 14.8s	remaining: 7.65s
# 66:	learn: 54631.5646005	total: 15s	remaining: 7.4s
# 67:	learn: 54362.4074681	total: 15s	remaining: 7.07s
# 68:	learn: 54066.5224299	total: 15.3s	remaining: 6.86s
# 69:	learn: 53825.1230499	total: 15.7s	remaining: 6.71s
# 70:	learn: 53615.0304038	total: 16s	remaining: 6.54s
# 71:	learn: 53345.2533758	total: 16.6s	remaining: 6.46s
# 72:	learn: 53069.8400033	total: 16.9s	remaining: 6.25s
# 73:	learn: 52823.6019706	total: 17.1s	remaining: 5.99s
# 74:	learn: 52537.1739637	total: 17.3s	remaining: 5.76s
# 75:	learn: 52291.1777884	total: 17.7s	remaining: 5.59s
# 76:	learn: 52060.1911068	total: 18.2s	remaining: 5.43s
# 77:	learn: 51843.7758368	total: 18.4s	remaining: 5.18s
# 78:	learn: 51563.7697384	total: 18.7s	remaining: 4.96s
# 79:	learn: 51327.2130193	total: 18.8s	remaining: 4.7s
# 80:	learn: 51075.7082545	total: 18.9s	remaining: 4.44s
# 81:	learn: 50866.0182390	total: 19.1s	remaining: 4.19s
# 82:	learn: 50610.0885064	total: 19.3s	remaining: 3.96s
# 83:	learn: 50388.9306468	total: 19.5s	remaining: 3.72s
# 84:	learn: 50154.7110163	total: 19.7s	remaining: 3.47s
# 85:	learn: 49917.3561329	total: 19.9s	remaining: 3.24s
# 86:	learn: 49654.7276130	total: 20.1s	remaining: 3.01s
# 87:	learn: 49446.0262339	total: 20.5s	remaining: 2.79s
# 88:	learn: 49209.8323084	total: 20.5s	remaining: 2.54s
# 89:	learn: 48966.1466429	total: 20.9s	remaining: 2.32s
# 90:	learn: 48732.4879906	total: 21.2s	remaining: 2.1s
# 91:	learn: 48529.3399046	total: 21.5s	remaining: 1.86s
# 92:	learn: 48314.2424210	total: 21.7s	remaining: 1.63s
# 93:	learn: 48094.5061300	total: 21.8s	remaining: 1.39s
# 94:	learn: 47844.3345558	total: 22s	remaining: 1.16s
# 95:	learn: 47634.1120398	total: 22.1s	remaining: 922ms
# 96:	learn: 47428.2779358	total: 22.5s	remaining: 695ms
# 97:	learn: 47196.0270896	total: 22.7s	remaining: 463ms
# 98:	learn: 46985.1523753	total: 22.9s	remaining: 231ms
# 99:	learn: 46755.8890936	total: 23s	remaining: 0us
# 86:	learn: 18420.8917174	total: 16.3s	remaining: 2.43s
# 87:	learn: 18259.5408118	total: 16.3s	remaining: 2.22s
# 88:	learn: 18117.3780089	total: 16.4s	remaining: 2.02s
# 89:	learn: 17942.1268815	total: 16.6s	remaining: 1.84s
# 90:	learn: 17755.5437068	total: 16.7s	remaining: 1.65s
# 91:	learn: 17615.4024596	total: 16.7s	remaining: 1.46s
# 92:	learn: 17488.2358692	total: 16.9s	remaining: 1.27s
# 93:	learn: 17343.3585220	total: 17s	remaining: 1.08s
# 94:	learn: 17180.7592624	total: 17.1s	remaining: 898ms
# 95:	learn: 17042.4075985	total: 17.1s	remaining: 713ms
# 96:	learn: 16919.4013992	total: 17.2s	remaining: 533ms
# 97:	learn: 16801.6756800	total: 17.3s	remaining: 353ms
# 98:	learn: 16680.0294960	total: 17.4s	remaining: 175ms
# 99:	learn: 16566.8363584	total: 17.4s	remaining: 0us
# 67:	learn: 56143.3808956	total: 14.2s	remaining: 6.68s
# 68:	learn: 55832.1544581	total: 14.5s	remaining: 6.5s
# 69:	learn: 55580.8175116	total: 14.6s	remaining: 6.24s
# 70:	learn: 55308.0746397	total: 14.7s	remaining: 6.01s
# 71:	learn: 55000.4009682	total: 14.8s	remaining: 5.75s
# 72:	learn: 54739.6232131	total: 15s	remaining: 5.56s
# 73:	learn: 54469.3789259	total: 15.2s	remaining: 5.34s
# 74:	learn: 54227.0366767	total: 15.6s	remaining: 5.21s
# 75:	learn: 53935.2840948	total: 15.7s	remaining: 4.95s
# 76:	learn: 53628.8462699	total: 15.8s	remaining: 4.73s
# 77:	learn: 53411.0975662	total: 15.9s	remaining: 4.49s
# 78:	learn: 53146.6431380	total: 16.1s	remaining: 4.27s
# 79:	learn: 52914.0531698	total: 16.4s	remaining: 4.1s
# 80:	learn: 52693.6991629	total: 16.7s	remaining: 3.92s
# 81:	learn: 52441.9196053	total: 16.9s	remaining: 3.7s
# 82:	learn: 52220.7879544	total: 16.9s	remaining: 3.47s
# 83:	learn: 51961.2683693	total: 17.2s	remaining: 3.28s
# 84:	learn: 51702.3204981	total: 17.3s	remaining: 3.06s
# 85:	learn: 51468.4635093	total: 17.6s	remaining: 2.87s
# 86:	learn: 51225.4002016	total: 17.7s	remaining: 2.64s
# 87:	learn: 50969.7543161	total: 18.1s	remaining: 2.46s
# 88:	learn: 50754.7153706	total: 18.2s	remaining: 2.25s
# 89:	learn: 50488.5358690	total: 18.3s	remaining: 2.03s
# 90:	learn: 50277.0114805	total: 18.5s	remaining: 1.83s
# 91:	learn: 50049.3661821	total: 18.7s	remaining: 1.62s
# 92:	learn: 49820.0885248	total: 18.8s	remaining: 1.42s
# 93:	learn: 49603.5167545	total: 19.1s	remaining: 1.22s
# 94:	learn: 49368.6195873	total: 19.2s	remaining: 1.01s
# 95:	learn: 49152.5789269	total: 19.3s	remaining: 803ms
# 96:	learn: 48948.6971361	total: 19.3s	remaining: 597ms
# 97:	learn: 48709.1354362	total: 19.5s	remaining: 398ms
# 98:	learn: 48471.8714024	total: 19.8s	remaining: 200ms
# 99:	learn: 48254.6458850	total: 20.1s	remaining: 0us
# 67:	learn: 22345.1775049	total: 12.5s	remaining: 5.87s
# 68:	learn: 22089.3595105	total: 12.7s	remaining: 5.7s
# 69:	learn: 21851.5255035	total: 12.9s	remaining: 5.55s
# 70:	learn: 21636.8080105	total: 13.2s	remaining: 5.39s
# 71:	learn: 21439.3079419	total: 13.3s	remaining: 5.18s
# 72:	learn: 21194.6439170	total: 13.5s	remaining: 4.98s
# 73:	learn: 20999.7247572	total: 13.7s	remaining: 4.81s
# 74:	learn: 20814.7343822	total: 13.9s	remaining: 4.62s
# 75:	learn: 20634.9176823	total: 14.1s	remaining: 4.45s
# 76:	learn: 20463.1512796	total: 14.4s	remaining: 4.3s
# 77:	learn: 20316.8045074	total: 14.6s	remaining: 4.1s
# 78:	learn: 20108.4698626	total: 14.9s	remaining: 3.95s
# 79:	learn: 19935.7478697	total: 15.1s	remaining: 3.78s
# 80:	learn: 19771.7479914	total: 15.5s	remaining: 3.64s
# 81:	learn: 19621.5027848	total: 15.9s	remaining: 3.48s
# 82:	learn: 19437.6948518	total: 16.1s	remaining: 3.3s
# 83:	learn: 19254.0354411	total: 16.3s	remaining: 3.11s
# 84:	learn: 19080.2445723	total: 16.4s	remaining: 2.9s
# 85:	learn: 18923.2324971	total: 16.6s	remaining: 2.7s
# 86:	learn: 18803.9219267	total: 16.8s	remaining: 2.51s
# 87:	learn: 18647.3141925	total: 17s	remaining: 2.31s
# 88:	learn: 18518.1366555	total: 17.1s	remaining: 2.12s
# 89:	learn: 18363.6718899	total: 17.5s	remaining: 1.95s
# 90:	learn: 18229.0068149	total: 18.1s	remaining: 1.79s
# 91:	learn: 18117.2451916	total: 18.3s	remaining: 1.59s
# 92:	learn: 17972.2042515	total: 18.6s	remaining: 1.4s
# 93:	learn: 17820.7428550	total: 18.7s	remaining: 1.19s
# 94:	learn: 17695.0858340	total: 18.9s	remaining: 993ms
# 95:	learn: 17583.6357909	total: 19.1s	remaining: 794ms
# 96:	learn: 17472.9437688	total: 19.2s	remaining: 593ms
# 97:	learn: 17364.4359461	total: 19.3s	remaining: 393ms
# 98:	learn: 17235.1569289	total: 19.3s	remaining: 195ms
# 99:	learn: 17119.9576997	total: 19.4s	remaining: 0us
# 76:	learn: 12495.2962490	total: 4.73s	remaining: 1.41s
# 77:	learn: 12350.9411982	total: 4.78s	remaining: 1.35s
# 78:	learn: 12215.4844885	total: 4.81s	remaining: 1.28s
# 79:	learn: 12038.2512206	total: 4.86s	remaining: 1.22s
# 80:	learn: 11944.5352087	total: 4.91s	remaining: 1.15s
# 81:	learn: 11818.3981552	total: 4.93s	remaining: 1.08s
# 82:	learn: 11702.3772420	total: 4.98s	remaining: 1.02s
# 83:	learn: 11653.7780662	total: 5s	remaining: 953ms
# 84:	learn: 11547.4157842	total: 5.03s	remaining: 888ms
# 85:	learn: 11471.3009207	total: 5.07s	remaining: 825ms
# 86:	learn: 11358.3438111	total: 5.1s	remaining: 762ms
# 87:	learn: 11263.7624050	total: 5.14s	remaining: 701ms
# 88:	learn: 11098.6861264	total: 5.2s	remaining: 643ms
# 89:	learn: 11007.1224701	total: 5.24s	remaining: 583ms
# 90:	learn: 10909.9882562	total: 5.29s	remaining: 523ms
# 91:	learn: 10824.1827975	total: 5.34s	remaining: 464ms
# 92:	learn: 10723.4857305	total: 5.41s	remaining: 407ms
# 93:	learn: 10657.7314401	total: 5.46s	remaining: 348ms
# 94:	learn: 10537.1670456	total: 5.49s	remaining: 289ms
# 95:	learn: 10426.7615981	total: 5.52s	remaining: 230ms
# 96:	learn: 10336.0806382	total: 5.56s	remaining: 172ms
# 97:	learn: 10253.8007600	total: 5.61s	remaining: 115ms
# 98:	learn: 10203.8115219	total: 5.63s	remaining: 56.9ms
# 99:	learn: 10121.9161985	total: 5.67s	remaining: 0us
# 97:	learn: 16645.5102888	total: 20.1s	remaining: 411ms
# 98:	learn: 16528.1459538	total: 20.4s	remaining: 206ms
# 99:	learn: 16410.7647459	total: 20.6s	remaining: 0us
# 99:	learn: 16551.0905108	total: 21.6s	remaining: 0us
# 86:	learn: 10489.5824022	total: 6.81s	remaining: 1.02s
# 87:	learn: 10377.9729544	total: 6.85s	remaining: 934ms
# 88:	learn: 10304.2349525	total: 6.9s	remaining: 853ms
# 89:	learn: 10170.8159469	total: 6.96s	remaining: 774ms
# 90:	learn: 10081.1277944	total: 7.01s	remaining: 693ms
# 91:	learn: 10000.5417801	total: 7.06s	remaining: 614ms
# 92:	learn: 9900.6638534	total: 7.09s	remaining: 534ms
# 93:	learn: 9780.0529324	total: 7.17s	remaining: 457ms
# 94:	learn: 9710.3857134	total: 7.2s	remaining: 379ms
# 95:	learn: 9580.2510345	total: 7.23s	remaining: 301ms
# 96:	learn: 9499.5245175	total: 7.25s	remaining: 224ms
# 97:	learn: 9401.9612681	total: 7.31s	remaining: 149ms
# 98:	learn: 9327.6039239	total: 7.33s	remaining: 74.1ms
# 99:	learn: 9316.8803978	total: 7.34s	remaining: 0us
# 77:	learn: 19174.8971991	total: 19s	remaining: 5.36s
# 78:	learn: 18995.5077776	total: 19.2s	remaining: 5.11s
# 79:	learn: 18834.8466822	total: 19.4s	remaining: 4.86s
# 80:	learn: 18692.3145011	total: 19.5s	remaining: 4.57s
# 81:	learn: 18511.2640110	total: 19.5s	remaining: 4.28s
# 82:	learn: 18345.3933552	total: 19.6s	remaining: 4.01s
# 83:	learn: 18183.4066142	total: 19.7s	remaining: 3.75s
# 84:	learn: 18030.2523338	total: 19.8s	remaining: 3.49s
# 85:	learn: 17865.4547951	total: 19.9s	remaining: 3.23s
# 86:	learn: 17727.8386542	total: 20s	remaining: 2.99s
# 87:	learn: 17603.0713175	total: 20.2s	remaining: 2.75s
# 88:	learn: 17481.2361951	total: 20.2s	remaining: 2.5s
# 89:	learn: 17327.2301317	total: 20.3s	remaining: 2.26s
# 90:	learn: 17201.9321397	total: 20.4s	remaining: 2.02s
# 91:	learn: 17066.7378630	total: 20.5s	remaining: 1.78s
# 92:	learn: 16909.7182488	total: 20.6s	remaining: 1.55s
# 93:	learn: 16811.2032660	total: 20.7s	remaining: 1.32s
# 94:	learn: 16678.0015339	total: 20.8s	remaining: 1.09s
# 95:	learn: 16567.9600094	total: 20.9s	remaining: 870ms
# 96:	learn: 16402.7356503	total: 21s	remaining: 649ms
# 97:	learn: 16288.5415330	total: 21.1s	remaining: 430ms
# 98:	learn: 16171.6578196	total: 21.1s	remaining: 214ms
# 99:	learn: 16030.8357862	total: 21.2s	remaining: 0us
# 58:	learn: 56984.5616825	total: 12.6s	remaining: 8.75s
# 59:	learn: 56716.9760654	total: 12.8s	remaining: 8.54s
# 60:	learn: 56437.0289272	total: 13.1s	remaining: 8.38s
# 61:	learn: 56165.3451800	total: 13.3s	remaining: 8.15s
# 62:	learn: 55900.9634809	total: 13.3s	remaining: 7.83s
# 63:	learn: 55611.3329969	total: 13.5s	remaining: 7.6s
# 64:	learn: 55325.5594732	total: 13.7s	remaining: 7.38s
# 65:	learn: 55025.7820096	total: 13.9s	remaining: 7.18s
# 66:	learn: 54764.9482517	total: 14.3s	remaining: 7.04s
# 67:	learn: 54493.6391607	total: 14.7s	remaining: 6.9s
# 68:	learn: 54233.5614597	total: 14.9s	remaining: 6.71s
# 69:	learn: 53955.9812354	total: 15s	remaining: 6.43s
# 70:	learn: 53684.7381382	total: 15.3s	remaining: 6.25s
# 71:	learn: 53439.8814994	total: 15.4s	remaining: 6s
# 72:	learn: 53214.5151376	total: 15.7s	remaining: 5.79s
# 73:	learn: 52965.2403743	total: 15.9s	remaining: 5.59s
# 74:	learn: 52678.7948283	total: 16.3s	remaining: 5.42s
# 75:	learn: 52402.9996674	total: 16.3s	remaining: 5.15s
# 76:	learn: 52162.8349083	total: 17s	remaining: 5.08s
# 77:	learn: 51924.6100438	total: 17.2s	remaining: 4.85s
# 78:	learn: 51686.6657099	total: 17.6s	remaining: 4.68s
# 79:	learn: 51437.5555425	total: 17.7s	remaining: 4.42s
# 80:	learn: 51198.1261817	total: 17.8s	remaining: 4.18s
# 81:	learn: 50952.9755249	total: 18s	remaining: 3.94s
# 82:	learn: 50729.1312261	total: 18.3s	remaining: 3.75s
# 83:	learn: 50475.2118014	total: 18.4s	remaining: 3.5s
# 84:	learn: 50244.6352317	total: 18.4s	remaining: 3.25s
# 85:	learn: 50014.9602966	total: 18.7s	remaining: 3.04s
# 86:	learn: 49784.0933083	total: 18.9s	remaining: 2.83s
# 87:	learn: 49560.2689770	total: 19.1s	remaining: 2.61s
# 88:	learn: 49329.0256382	total: 19.5s	remaining: 2.4s
# 89:	learn: 49083.9300278	total: 19.7s	remaining: 2.19s
# 90:	learn: 48863.2040535	total: 20s	remaining: 1.98s
# 91:	learn: 48664.4890296	total: 20.2s	remaining: 1.76s
# 92:	learn: 48432.4308513	total: 20.6s	remaining: 1.55s
# 93:	learn: 48226.6768590	total: 20.7s	remaining: 1.32s
# 94:	learn: 48006.7924067	total: 21s	remaining: 1.1s
# 95:	learn: 47809.5816138	total: 21s	remaining: 875ms
# 96:	learn: 47600.1184710	total: 21.1s	remaining: 653ms
# 97:	learn: 47368.6447337	total: 21.3s	remaining: 434ms
# 98:	learn: 47142.3150407	total: 21.5s	remaining: 217ms
# 99:	learn: 46931.2169314	total: 21.7s	remaining: 0us
# 0:	learn: 76350.9561949	total: 255ms	remaining: 25.3s
# 1:	learn: 71753.6566736	total: 405ms	remaining: 19.8s
# 2:	learn: 67635.9103608	total: 524ms	remaining: 16.9s
# 3:	learn: 63727.4793374	total: 606ms	remaining: 14.5s
# 4:	learn: 60336.6598124	total: 929ms	remaining: 17.6s
# 5:	learn: 57068.7925722	total: 1.16s	remaining: 18.1s
# 6:	learn: 54270.7642174	total: 1.32s	remaining: 17.6s
# 7:	learn: 51707.7994548	total: 1.49s	remaining: 17.2s
# 8:	learn: 49312.9541881	total: 1.69s	remaining: 17.1s
# 9:	learn: 47209.8964897	total: 1.83s	remaining: 16.5s
# 10:	learn: 45168.4831374	total: 1.94s	remaining: 15.7s
# 11:	learn: 43455.3054741	total: 2.1s	remaining: 15.4s
# 12:	learn: 41574.0566504	total: 2.33s	remaining: 15.6s
# 13:	learn: 40105.3518407	total: 2.43s	remaining: 14.9s
# 14:	learn: 38528.3922361	total: 2.65s	remaining: 15s
# 15:	learn: 37306.9693115	total: 2.71s	remaining: 14.2s
# 16:	learn: 36066.2781869	total: 2.81s	remaining: 13.7s
# 17:	learn: 34611.8407943	total: 2.88s	remaining: 13.1s
# 18:	learn: 33585.9331045	total: 2.96s	remaining: 12.6s
# 19:	learn: 32620.1715243	total: 3.04s	remaining: 12.2s
# 20:	learn: 31686.6730730	total: 3.21s	remaining: 12.1s
# 21:	learn: 30697.6624861	total: 3.32s	remaining: 11.8s
# 22:	learn: 29783.1714964	total: 3.49s	remaining: 11.7s
# 23:	learn: 29005.7955221	total: 3.58s	remaining: 11.3s
# 24:	learn: 28232.9012184	total: 3.64s	remaining: 10.9s
# 25:	learn: 27511.6050306	total: 3.71s	remaining: 10.5s
# 26:	learn: 26824.4375444	total: 3.75s	remaining: 10.2s
# 27:	learn: 26123.5744881	total: 3.76s	remaining: 9.67s
# 28:	learn: 25476.5592229	total: 3.83s	remaining: 9.38s
# 29:	learn: 24944.2399922	total: 3.85s	remaining: 8.99s
# 30:	learn: 24430.8949954	total: 3.91s	remaining: 8.71s
# 31:	learn: 23984.3426593	total: 3.98s	remaining: 8.46s
# 32:	learn: 23478.8932539	total: 4.01s	remaining: 8.15s
# 33:	learn: 22931.6046293	total: 4.06s	remaining: 7.88s
# 34:	learn: 22488.3500305	total: 4.1s	remaining: 7.62s
# 35:	learn: 22032.2036760	total: 4.17s	remaining: 7.42s
# 36:	learn: 21680.5783956	total: 4.22s	remaining: 7.18s
# 37:	learn: 21263.5166852	total: 4.26s	remaining: 6.95s
# 38:	learn: 20883.2572222	total: 4.3s	remaining: 6.72s
# 39:	learn: 20535.6288113	total: 4.35s	remaining: 6.52s
# 40:	learn: 20234.0421440	total: 4.38s	remaining: 6.31s
# 41:	learn: 19831.8865191	total: 4.41s	remaining: 6.09s
# 42:	learn: 19531.5098459	total: 4.45s	remaining: 5.9s
# 43:	learn: 19265.9382351	total: 4.47s	remaining: 5.69s
# 44:	learn: 19034.0627119	total: 4.49s	remaining: 5.48s
# 45:	learn: 18737.5052894	total: 4.52s	remaining: 5.3s
# 46:	learn: 18460.2751898	total: 4.57s	remaining: 5.15s
# 47:	learn: 18179.5176636	total: 4.6s	remaining: 4.98s
# 48:	learn: 17889.3836249	total: 4.62s	remaining: 4.81s
# 49:	learn: 17662.1972757	total: 4.65s	remaining: 4.65s
# 50:	learn: 17457.3284494	total: 4.68s	remaining: 4.5s
# 51:	learn: 17214.0761209	total: 4.7s	remaining: 4.34s
# 52:	learn: 17004.1631345	total: 4.74s	remaining: 4.21s
# 53:	learn: 16738.4182302	total: 4.79s	remaining: 4.08s
# 54:	learn: 16475.8061385	total: 4.83s	remaining: 3.95s
# 55:	learn: 16282.8507126	total: 4.86s	remaining: 3.82s
# 56:	learn: 16077.0619784	total: 4.9s	remaining: 3.7s
# 57:	learn: 15856.9600371	total: 4.93s	remaining: 3.57s
# 58:	learn: 15721.3316258	total: 4.96s	remaining: 3.44s
# 59:	learn: 15608.1731811	total: 4.98s	remaining: 3.32s
# 60:	learn: 15432.7580212	total: 5.02s	remaining: 3.21s
# 61:	learn: 15273.8173645	total: 5.05s	remaining: 3.1s
# 62:	learn: 15045.9546924	total: 5.08s	remaining: 2.98s
# 63:	learn: 14797.7880470	total: 5.12s	remaining: 2.88s
# 64:	learn: 14633.2225014	total: 5.14s	remaining: 2.77s
# 65:	learn: 14496.4067799	total: 5.17s	remaining: 2.66s
# 66:	learn: 14287.5347021	total: 5.19s	remaining: 2.56s
# 67:	learn: 14160.9455929	total: 5.23s	remaining: 2.46s
# 68:	learn: 13983.2266135	total: 5.26s	remaining: 2.37s
# 69:	learn: 13817.4739682	total: 5.3s	remaining: 2.27s
# 70:	learn: 13662.5333815	total: 5.32s	remaining: 2.17s
# 71:	learn: 13469.6631395	total: 5.36s	remaining: 2.08s
# 72:	learn: 13324.1699187	total: 5.39s	remaining: 1.99s
# 73:	learn: 13224.6165725	total: 5.43s	remaining: 1.91s
# 74:	learn: 13110.8205066	total: 5.45s	remaining: 1.82s
# 75:	learn: 12923.0966106	total: 5.48s	remaining: 1.73s
# 76:	learn: 12790.1568755	total: 5.53s	remaining: 1.65s
# 77:	learn: 12647.3744691	total: 5.55s	remaining: 1.56s
# 78:	learn: 12551.6860563	total: 5.59s	remaining: 1.49s
# 79:	learn: 12445.7583844	total: 5.62s	remaining: 1.41s
# 80:	learn: 12354.2553019	total: 5.66s	remaining: 1.33s
# 81:	learn: 12270.3174033	total: 5.7s	remaining: 1.25s
# 82:	learn: 12172.9179360	total: 5.75s	remaining: 1.18s
# 83:	learn: 12092.3061404	total: 5.79s	remaining: 1.1s
# 84:	learn: 12006.4985519	total: 5.84s	remaining: 1.03s
# 85:	learn: 11919.0740585	total: 5.88s	remaining: 957ms
# 86:	learn: 11787.9564395	total: 5.91s	remaining: 883ms
# 87:	learn: 11723.0430950	total: 5.97s	remaining: 814ms
# 88:	learn: 11615.0572275	total: 6.01s	remaining: 743ms
# 89:	learn: 11467.3289656	total: 6.06s	remaining: 673ms
# 90:	learn: 11397.6789196	total: 6.11s	remaining: 605ms
# 91:	learn: 11306.7897813	total: 6.16s	remaining: 536ms
# 92:	learn: 11214.1259066	total: 6.22s	remaining: 468ms
# 93:	learn: 11148.2250360	total: 6.26s	remaining: 400ms
# 94:	learn: 10998.2194723	total: 6.29s	remaining: 331ms
# 95:	learn: 10911.0108461	total: 6.32s	remaining: 263ms
# 96:	learn: 10792.8160811	total: 6.34s	remaining: 196ms
# 97:	learn: 10684.0626644	total: 6.36s	remaining: 130ms
# 98:	learn: 10591.9135064	total: 6.37s	remaining: 64.4ms
# 99:	learn: 10442.1707709	total: 6.38s	remaining: 0us
# 37:	learn: 19991.8698391	total: 8.57s	remaining: 14s
# 38:	learn: 19753.7749746	total: 8.87s	remaining: 13.9s
# 39:	learn: 19454.4098170	total: 9.01s	remaining: 13.5s
# 40:	learn: 19108.9397176	total: 9.12s	remaining: 13.1s
# 41:	learn: 18781.0147438	total: 9.23s	remaining: 12.7s
# 42:	learn: 18493.1008976	total: 9.38s	remaining: 12.4s
# 43:	learn: 18163.0805436	total: 9.55s	remaining: 12.2s
# 44:	learn: 17914.2068853	total: 9.65s	remaining: 11.8s
# 45:	learn: 17673.9534834	total: 9.85s	remaining: 11.6s
# 46:	learn: 17364.8153220	total: 10.2s	remaining: 11.5s
# 47:	learn: 17146.7751404	total: 10.4s	remaining: 11.3s
# 48:	learn: 16968.6479780	total: 10.6s	remaining: 11s
# 49:	learn: 16683.6759914	total: 10.8s	remaining: 10.8s
# 50:	learn: 16469.0179473	total: 10.9s	remaining: 10.5s
# 51:	learn: 16235.7281809	total: 11.2s	remaining: 10.3s
# 52:	learn: 16084.3206186	total: 11.5s	remaining: 10.2s
# 53:	learn: 15906.8265213	total: 11.6s	remaining: 9.91s
# 54:	learn: 15731.8465736	total: 11.8s	remaining: 9.66s
# 55:	learn: 15548.2613014	total: 11.9s	remaining: 9.36s
# 56:	learn: 15392.7139980	total: 12s	remaining: 9.02s
# 57:	learn: 15290.6111260	total: 12.2s	remaining: 8.8s
# 58:	learn: 15149.6149918	total: 12.3s	remaining: 8.55s
# 59:	learn: 15007.6326365	total: 12.5s	remaining: 8.32s
# 60:	learn: 14876.5482214	total: 12.6s	remaining: 8.07s
# 61:	learn: 14732.0626128	total: 12.8s	remaining: 7.83s
# 62:	learn: 14555.3776710	total: 13s	remaining: 7.62s
# 63:	learn: 14485.8542856	total: 13.2s	remaining: 7.41s
# 64:	learn: 14299.1473603	total: 13.3s	remaining: 7.17s
# 65:	learn: 14181.7380055	total: 13.4s	remaining: 6.91s
# 66:	learn: 13991.6700054	total: 13.5s	remaining: 6.65s
# 67:	learn: 13841.7609296	total: 13.7s	remaining: 6.45s
# 68:	learn: 13671.0928307	total: 13.8s	remaining: 6.21s
# 69:	learn: 13506.8213859	total: 14s	remaining: 6s
# 70:	learn: 13369.9012212	total: 14.1s	remaining: 5.75s
# 71:	learn: 13219.9046741	total: 14.3s	remaining: 5.56s
# 72:	learn: 13051.5939431	total: 14.4s	remaining: 5.32s
# 73:	learn: 12936.1990544	total: 14.6s	remaining: 5.12s
# 74:	learn: 12810.3075942	total: 14.9s	remaining: 4.98s
# 75:	learn: 12647.3242794	total: 15.2s	remaining: 4.79s
# 76:	learn: 12489.9667061	total: 15.3s	remaining: 4.57s
# 77:	learn: 12399.1498457	total: 15.4s	remaining: 4.34s
# 78:	learn: 12308.9672586	total: 15.5s	remaining: 4.12s
# 79:	learn: 12206.7269761	total: 15.6s	remaining: 3.91s
# 80:	learn: 12111.5164789	total: 15.7s	remaining: 3.69s
# 81:	learn: 12006.1595926	total: 15.8s	remaining: 3.47s
# 82:	learn: 11874.4563918	total: 15.9s	remaining: 3.25s
# 83:	learn: 11711.3594341	total: 16s	remaining: 3.06s
# 84:	learn: 11651.7619784	total: 16.2s	remaining: 2.85s
# 85:	learn: 11485.3757462	total: 16.3s	remaining: 2.66s
# 86:	learn: 11396.8563598	total: 16.4s	remaining: 2.46s
# 87:	learn: 11328.3949962	total: 16.6s	remaining: 2.26s
# 88:	learn: 11236.4906801	total: 16.6s	remaining: 2.05s
# 89:	learn: 11135.0937813	total: 16.7s	remaining: 1.85s
# 90:	learn: 10962.7422115	total: 16.7s	remaining: 1.65s
# 91:	learn: 10846.5182658	total: 16.8s	remaining: 1.46s
# 92:	learn: 10764.6520092	total: 16.9s	remaining: 1.27s
# 93:	learn: 10641.1396449	total: 16.9s	remaining: 1.08s
# 94:	learn: 10564.8262287	total: 17s	remaining: 895ms
# 95:	learn: 10480.2240453	total: 17.1s	remaining: 713ms
# 96:	learn: 10444.8091272	total: 17.2s	remaining: 532ms
# 97:	learn: 10382.9722696	total: 17.3s	remaining: 352ms
# 98:	learn: 10280.9295421	total: 17.4s	remaining: 176ms
# 99:	learn: 10149.7955864	total: 17.5s	remaining: 0us
